# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from openpyxl import load_workbook, Workbook
from datetime import datetime
import os
import time
import pandas as pd
import re
import shutil
# Função para inserir a data atual no campo "txtInicio"
def inserir_data_atual(navegador):
    # Obtendo a data atual no formato DD/MM/AAAA
    data_atual = datetime.now().strftime("%d/%m/%Y")
    
    # Esperando o campo "txtInicio" estar presente e visível
    campo_data_inicio = WebDriverWait(navegador, 10).until(
        EC.visibility_of_element_located((By.NAME, "txtInicio"))
    )
    
    # Limpando o campo e inserindo a data atual
    campo_data_inicio.clear()
    campo_data_inicio.send_keys(data_atual)

# Inicializando o navegador Chrome
navegador = webdriver.Chrome()
navegador.get("https://spe.findes.org.br/index")

# Aguardando até que os campos de login estejam presentes
WebDriverWait(navegador, 10).until(EC.presence_of_element_located((By.NAME, "txtLogin")))

# Preenchendo os campos de login e senha
navegador.find_element(By.NAME, "txtLogin").send_keys("166.957.737-69")
navegador.find_element(By.NAME, "txtSenha").send_keys("166.957.737-69")

# Selecionando a opção "SENAI VITÓRIA" no campo selectInstituicao
navegador.find_element(By.NAME, "selectInstituicao").send_keys("SENAI VITÓRIA")

# Clicando no botão de login usando espera explícita
botao_entrar = WebDriverWait(navegador, 10).until(EC.element_to_be_clickable((By.ID, "btnLogar")))
botao_entrar.click()

# Aguardando e clicando no botão de menu
botao_menu = WebDriverWait(navegador, 10).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/nav/ul[1]/li[1]/a')))
botao_menu.click()

# Aguardando e clicando no botão de relatório
botao_relatorio = WebDriverWait(navegador, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="gerenciarRelatorio"]')))
botao_relatorio.click()

# Selecionando o relatório
selecionar_relatorio = WebDriverWait(navegador, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="sidebarMenu"]/ul/li[16]/ul/li[1]/a')))
selecionar_relatorio.click()

# Inserindo a data atual no campo "txtInicio"
inserir_data_atual(navegador)

# Esperando o campo "txtFim" e preenchendo com a data desejada
campo_data_fim = WebDriverWait(navegador, 10).until(
    EC.visibility_of_element_located((By.NAME, "txtFim"))
)
campo_data_fim.clear()
campo_data_fim.send_keys("31/12/2024")

# Aguardando até que o dropdown "Horario_length" esteja disponível
mostrar_todos_dropdown = WebDriverWait(navegador, 20).until(
    EC.presence_of_element_located((By.NAME, "Horario_length"))
)

# Usando Select para selecionar a opção "Todos"
select_mostrar_todos = Select(mostrar_todos_dropdown)
select_mostrar_todos.select_by_visible_text("Todos")

# Esperando até que o botão Excel esteja clicável
botao_excel = WebDriverWait(navegador, 10).until(
    EC.element_to_be_clickable((By.XPATH, '//*[@id="Horario_wrapper"]/div[1]/button[1]'))
)

# Rolando até o botão Excel para garantir que esteja visível
navegador.execute_script("arguments[0].scrollIntoView(true);", botao_excel)

# Tentando clicar no botão usando JavaScript se o clique normal falhar
try:
    botao_excel.click()
except:
    navegador.execute_script("arguments[0].click();", botao_excel)


import os
import re
import shutil
from openpyxl import load_workbook, Workbook
from openpyxl.styles import PatternFill, Border, Side

# Função para identificar o último arquivo baixado com uma extensão específica
def encontrar_ultimo_arquivo_baixado(diretorio_downloads, extensao=".xlsx"):
    # Listando os arquivos no diretório de downloads com a extensão correta
    arquivos = [f for f in os.listdir(diretorio_downloads) if f.endswith(extensao)]
    
    # Verificando se existem arquivos com a extensão desejada
    if not arquivos:
        raise FileNotFoundError(f"Nenhum arquivo com a extensão {extensao} encontrado em {diretorio_downloads}")
    
    # Verificando o caminho completo de cada arquivo e retornando o mais recente
    caminhos_arquivos = [os.path.join(diretorio_downloads, arquivo) for arquivo in arquivos]
    ultimo_arquivo = max(caminhos_arquivos, key=os.path.getmtime)
    return ultimo_arquivo

# Função para mover o arquivo baixado para outro diretório
def mover_arquivo(caminho_arquivo, destino):
    if not os.path.exists(destino):
        os.makedirs(destino)  # Cria o diretório de destino, caso ele não exista
    novo_caminho = os.path.join(destino, os.path.basename(caminho_arquivo))
    shutil.move(caminho_arquivo, novo_caminho)
    return novo_caminho

# Caminho do diretório de downloads (modifique conforme seu sistema)
diretorio_downloads = os.path.expanduser("~/Downloads")

# Diretório de destino para onde o arquivo será movido
diretorio_destino = os.path.expanduser(r"C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2")

# Encontrando o último arquivo baixado com extensão .xlsx
try:
    NOME_ARQUIVO = encontrar_ultimo_arquivo_baixado(diretorio_downloads, extensao=".xlsx")
except FileNotFoundError as e:
    print(e)
    NOME_ARQUIVO = None

# Se encontrou o arquivo, movê-lo para o diretório de destino e processá-lo
if NOME_ARQUIVO:
    novo_caminho_arquivo = mover_arquivo(NOME_ARQUIVO, diretorio_destino)

    # Se o arquivo foi movido com sucesso, processá-lo
    if os.path.exists(novo_caminho_arquivo):
        print(f"Arquivo movido para: {novo_caminho_arquivo}")

        # Função para carregar a planilha
        def carregar_planilha(caminho_arquivo):
            return load_workbook(filename=caminho_arquivo)

        # Função para limpar o nome da aba
        def limpar_nome_aba(nome):
            if nome is None:
                return "Sem_Nome"
            return re.sub(r'[\\/*?:[\]]', '', nome)[:31]

        # Função para criar ou obter uma aba existente
        def obter_ou_criar_aba(workbook, nome_aba):
            if nome_aba in workbook.sheetnames:
                return workbook[nome_aba]
            nova_aba = workbook.create_sheet(title=nome_aba)
            adicionar_titulos(nova_aba)
            return nova_aba

        # Função para adicionar os títulos das colunas
        def adicionar_titulos(aba):
            aba['A1'] = "Data"
            aba['B1'] = "Horário de Início"
            aba['C1'] = "Horário de Fim"
            aba['D1'] = "Turma"

        # Função para preencher a aba com os dados
        def preencher_aba(aba, dados):
            linha = len(aba['A']) + 1  # Encontrar a próxima linha disponível
            aba[f"A{linha}"] = dados['data']
            aba[f"B{linha}"] = dados['inicio']
            aba[f"C{linha}"] = dados['fim']
            aba[f"D{linha}"] = dados['turma']

        # Função para extrair dados de uma linha da planilha principal
        def extrair_dados_linha(sheet, linha):
            return {
                'data': sheet[f"A{linha}"].value,
                'inicio': sheet[f"C{linha}"].value,
                'fim': sheet[f"D{linha}"].value,
                'turma': sheet[f"E{linha}"].value
            }

        # Função principal para processar a planilha
        def processar_planilha(nome_arquivo):
            workbook = carregar_planilha(nome_arquivo)
            sheet_principal = workbook.active

            # Dicionário para manter o controle das novas planilhas por instrutor
            planilhas_instrutores = {}

            # Processar os dados de cada linha
            for linha in range(2, len(sheet_principal['F']) + 1):
                nome_instrutor = limpar_nome_aba(sheet_principal[f'F{linha}'].value)

                if nome_instrutor not in planilhas_instrutores:
                    planilhas_instrutores[nome_instrutor] = Workbook()
                    selecionaSheetInstrutor = planilhas_instrutores[nome_instrutor].active
                    selecionaSheetInstrutor.title = "Instrutores"

                    # Preenche os títulos das colunas na nova planilha do instrutor
                    adicionar_titulos(selecionaSheetInstrutor)

                aba_instrutor = planilhas_instrutores[nome_instrutor]
                dados_instrutor = extrair_dados_linha(sheet_principal, linha)
                preencher_aba(aba_instrutor['Instrutores'], dados_instrutor)

            # Salvar cada nova planilha de instrutor
            for nome_instrutor, workbook_instrutor in planilhas_instrutores.items():
                caminho_nova_planilha = os.path.join(diretorio_destino, f"{nome_instrutor}.xlsx")
                workbook_instrutor.save(filename=caminho_nova_planilha)
                print(f"Nova planilha criada para {nome_instrutor}: {caminho_nova_planilha}")

            # Salvar as alterações na planilha principal
            workbook.save(filename=nome_arquivo)
            os.startfile(nome_arquivo)

        # Executar o processamento da planilha
        processar_planilha(novo_caminho_arquivo)
    else:
        print("Erro: O arquivo não foi movido corretamente.")
else:
    print("Nenhum arquivo encontrado para processar.")

import win32com.client as win32


outlook = win32.Dispatch('outlook.application')

nome_arquivo = r"C:\Users\fgpaula\Desktop\automatização\Lista de Email\Lista de Email.xlsx"

# Carregar a planilha
planilha_aberta = load_workbook(filename=nome_arquivo)
sheet_selecionada = planilha_aberta['Dados']

for linha in range(2, len(sheet_selecionada['A']) + 1):
    
    nome = sheet_selecionada['A%s' % linha].value
    nomeCompleto = sheet_selecionada['B%s' % linha].value
    email = sheet_selecionada['C%s' % linha].value
    
    emailOutlook = outlook.CreateItem(0)

    emailOutlook.To = email
    emailOutlook.Subject = "Horário " + nomeCompleto
    emailOutlook.HTMLBody = f"""
    <p>Boa noite <b>{nome}</b>.</p>
    <p>Segue seu horário referente a segunda quinzena do mês.</p>
    <p>Atenciosamente.</p>
    <p><img src="C:\\Assinatura\\Udemy Assinatura.jpg">.</p>
    """
    
    anexoEmail = "C:\\Users\\fgpaula\\Desktop\\automatização\\HORARIO INSTRUTORES\\SET 2\\" + nomeCompleto + ".xlsx"
    
    # Verifica se o arquivo existe antes de anexar
    if os.path.exists(anexoEmail):
        emailOutlook.Attachments.Add(anexoEmail)
    else:
        print(f"Erro: O arquivo {anexoEmail} não foi encontrado.")

    emailOutlook.save()  # save = Cria e salva o email, Send() - Enviar o email
# Out:
# Arquivo movido para: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\Consultar-Horário - 2024-09-26T164537.496.xlsx
# Nova planilha criada para Sem_Nome: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\Sem_Nome.xlsx
# Nova planilha criada para InstrutorAmbiente Reserva: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\InstrutorAmbiente Reserva.xlsx
# Nova planilha criada para HEISTHEN MAZZEI SCARPARO: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\HEISTHEN MAZZEI SCARPARO.xlsx
# Nova planilha criada para NICOLAU TECIANELLI COUTINHO: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\NICOLAU TECIANELLI COUTINHO.xlsx
# Nova planilha criada para JOEL HERBERT BARBOSA SILVA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\JOEL HERBERT BARBOSA SILVA.xlsx
# Nova planilha criada para JOAO BATISTA JULIATTI: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\JOAO BATISTA JULIATTI.xlsx
# Nova planilha criada para JOAO MARCIANO DA SILVA JUNIOR: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\JOAO MARCIANO DA SILVA JUNIOR.xlsx
# Nova planilha criada para MARLI BROMMENSCHENKEL BARRETO: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\MARLI BROMMENSCHENKEL BARRETO.xlsx
# Nova planilha criada para SAMUEL DE PAULO MADEIRA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\SAMUEL DE PAULO MADEIRA.xlsx
# Nova planilha criada para MARCOS TADEU VICENTE ALVES: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\MARCOS TADEU VICENTE ALVES.xlsx
# Nova planilha criada para MAURICIO DE JESUS DAVEL: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\MAURICIO DE JESUS DAVEL.xlsx
# Nova planilha criada para SANDRO SANTOS SILVA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\SANDRO SANTOS SILVA.xlsx
# Nova planilha criada para GREGORY VELOSO SILVA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\GREGORY VELOSO SILVA.xlsx
# Nova planilha criada para PABLO PAULINO JERONIMO DOS SANT: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\PABLO PAULINO JERONIMO DOS SANT.xlsx
# Nova planilha criada para BERNARDO PEREIRA SOSSAI: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\BERNARDO PEREIRA SOSSAI.xlsx
# Nova planilha criada para CYNTHIA LOUISE RIBEIRO FERREIRA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\CYNTHIA LOUISE RIBEIRO FERREIRA.xlsx
# Nova planilha criada para CARLOS EDUARDO OLIVEIRA MILANEZ: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\CARLOS EDUARDO OLIVEIRA MILANEZ.xlsx
# Nova planilha criada para JACO FRANCA CONCEICAO ROMANHA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\JACO FRANCA CONCEICAO ROMANHA.xlsx
# Nova planilha criada para RAMON DE HOLANDA NASCIMENTO: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\RAMON DE HOLANDA NASCIMENTO.xlsx
# Nova planilha criada para JONAS BARBOSA DA SILVA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\JONAS BARBOSA DA SILVA.xlsx
# Nova planilha criada para MYKAEL DOS SANTOS DEOLINDO: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\MYKAEL DOS SANTOS DEOLINDO.xlsx
# Nova planilha criada para ANDRE NASCIMENTO SARAIVA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\ANDRE NASCIMENTO SARAIVA.xlsx
# Nova planilha criada para THADEU VASCONCELOS DA SILVA GOM: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\THADEU VASCONCELOS DA SILVA GOM.xlsx
# Nova planilha criada para RODRIGO DE SOUZA PORTELA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\RODRIGO DE SOUZA PORTELA.xlsx
# Nova planilha criada para TIAGO FERREIRA BEZERRA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\TIAGO FERREIRA BEZERRA.xlsx
# Nova planilha criada para FABRICIO PLASTER: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\FABRICIO PLASTER.xlsx
# Nova planilha criada para CAMILA DOS SANTOS PINTO SOARES: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\CAMILA DOS SANTOS PINTO SOARES.xlsx
# Nova planilha criada para JULIO CESAR NUNES ALVARENGA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\JULIO CESAR NUNES ALVARENGA.xlsx
# Nova planilha criada para ALVIMAR DOS REIS VENTUROTI: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\ALVIMAR DOS REIS VENTUROTI.xlsx
# Nova planilha criada para RENISSON RODRIGUES DE SOUZA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\RENISSON RODRIGUES DE SOUZA.xlsx
# Nova planilha criada para KARLOMAGNO FREITAS STEDILE: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\KARLOMAGNO FREITAS STEDILE.xlsx
# Nova planilha criada para ISABEL MARIA ROCHA BUSTAMANTE: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\ISABEL MARIA ROCHA BUSTAMANTE.xlsx
# Nova planilha criada para JOSE LUCAS CAMPOS: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\JOSE LUCAS CAMPOS.xlsx
# Nova planilha criada para DOUGLAS SOARES DE LIMA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\DOUGLAS SOARES DE LIMA.xlsx
# Nova planilha criada para GISLAINE FERREIRA DE SOUSA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\GISLAINE FERREIRA DE SOUSA.xlsx
# Nova planilha criada para LUCAS LAIGNIER SOUZA CORREA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\LUCAS LAIGNIER SOUZA CORREA.xlsx
# Nova planilha criada para LUIZ EDUARDO FARIAS CASTELO: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\LUIZ EDUARDO FARIAS CASTELO.xlsx
# Nova planilha criada para LARISSA GOMES DA SILVA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\LARISSA GOMES DA SILVA.xlsx
# Nova planilha criada para ROGERIO FABIO SUAVE: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\ROGERIO FABIO SUAVE.xlsx
# Nova planilha criada para SERGIO OLIVEIRA BRITO DA SILVA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\SERGIO OLIVEIRA BRITO DA SILVA.xlsx
# Nova planilha criada para SANDRO CRISTIANO SANTOS DA COST: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\SANDRO CRISTIANO SANTOS DA COST.xlsx
# Nova planilha criada para AMINTA DEL VALLE MANZANILLA GAL: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\AMINTA DEL VALLE MANZANILLA GAL.xlsx
# Nova planilha criada para DANIEL AZEREDO SEIDEL: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\DANIEL AZEREDO SEIDEL.xlsx
# Nova planilha criada para DANIEL BRAVIM LEMOS: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\DANIEL BRAVIM LEMOS.xlsx
# Nova planilha criada para JULIO CEZAR PAGIO: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\JULIO CEZAR PAGIO.xlsx
# Nova planilha criada para RODRIGO DE OLIVEIRA MACHADO: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\RODRIGO DE OLIVEIRA MACHADO.xlsx
# Nova planilha criada para EDSON BULHOES: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\EDSON BULHOES.xlsx
# Nova planilha criada para ANDERSON GONÇALVES PARDINHO: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\ANDERSON GONÇALVES PARDINHO.xlsx
# Nova planilha criada para FABIANO FRANCISCO DE PAULA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\FABIANO FRANCISCO DE PAULA.xlsx
# Nova planilha criada para ADEMIR CARLOS PIN: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\ADEMIR CARLOS PIN.xlsx
# Nova planilha criada para EDUARDO LUIZ FERREIRA SILVA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\EDUARDO LUIZ FERREIRA SILVA.xlsx
# Nova planilha criada para PIETRA LOPES DE MEDEIROS: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\PIETRA LOPES DE MEDEIROS.xlsx
# Nova planilha criada para JOSANIO DE SOUZA PEREIRA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\JOSANIO DE SOUZA PEREIRA.xlsx
# Nova planilha criada para AFONSO DE JESUS CORDEIRO: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\AFONSO DE JESUS CORDEIRO.xlsx
# Nova planilha criada para FERNANDO TADEU RIOS DIAS: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\FERNANDO TADEU RIOS DIAS.xlsx
# Nova planilha criada para STEPHANY GHIOTTO LIMA BINO SERR: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\STEPHANY GHIOTTO LIMA BINO SERR.xlsx
# Nova planilha criada para DOUGLAS DOS SANTOS BROESCHALDT: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\DOUGLAS DOS SANTOS BROESCHALDT.xlsx
# Nova planilha criada para EDUARDO FERREIRA GUERRA: C:\Users\fgpaula\Desktop\automatização\HORARIO INSTRUTORES\SET 2\EDUARDO FERREIRA GUERRA.xlsx
